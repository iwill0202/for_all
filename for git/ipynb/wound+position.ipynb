# %%
wound = [u'大量出血',u'內出血',u'化學性燒燙傷',u'化學性燒燙傷',u'水腦症',u'出血',u'出血性休克',u'外傷'\
         ,u'外傷性腦出血',u'甩鞭式傷害',u'多處擦傷',u'肌肉拉傷',u'肌肉異常',u'肌肉痙攣壓痛',u'肌肉較緊感'\
         ,u'肌張力異常症',u'肌腱炎',u'血氣胸',u'血胸',u'血腫',u'吸入性肺損傷',u'坐骨神經痛',u'扭傷'\
         ,u'折出血休克',u'受傷',u'呼吸衰竭',u'拉傷',u'肢體偏癱',u'表淺損傷',u'青光眼',u'活動受到侷限'\
         ,u'穿刺性骨折',u'紅腫',u'重度脫臼',u'挫傷',u'挫擦傷',u'浮腫',u'疼痛',u'病變',u'眩暈',u'破裂'\
         ,u'破損',u'神經根受損',u'神經根病變',u'神經根病變傷害',u'神經麻痺',u'神經損傷',u'神經壓迫'\
         ,u'神經叢病變',u'粉碎性骨折',u'缺氧性腦症中樞性衰竭',u'缺氧性腦症中樞性衰竭',u'缺損',u'胸悶'\
         ,u'脊椎病變',u'脊髓空洞症',u'脊髓損傷',u'退化性脊椎炎',u'退化性脊椎病變',u'退化性頸椎炎'\
         ,u'馬鞭症候群',u'骨折',u'骨折出血',u'骨折破裂',u'骨刺增生',u'骨斷裂',u'側重擊',u'梗塞',u'淤傷'\
         ,u'眼外傷性視神經病變',u'第二度燙傷',u'脫臼',u'脫位',u'閉鎖性骨折',u'創傷',u'散狀淤傷'\
         ,u'椎間盤凸出',u'椎間盤突出',u'椎間盤突出壓迫頸部脊髓',u'椎間盤移位',u'椎間盤脫出',u'無法支撐挺直'\
         ,u'無法任意轉動',u'無法擺正',u'痛',u'痠疼',u'發炎',u'硬化症',u'硬腦膜上腔出血',u'筋膜炎'\
         ,u'腔室症候群',u'鈍力挫傷',u'鈍挫傷',u'鈍傷',u'鈍銼傷',u'開放性骨折',u'開放性傷口'\
         ,u'傷口',u'傷害',u'損傷',u'暈眩',u'滑脫',u'滑脫症',u'瘀血',u'瘀青',u'瘀傷',u'瘀腫',u'腦部傷害致'\
         ,u'腦漿溢出',u'腦震盪',u'腫瘤',u'嘔吐',u'截肢',u'緊感',u'酸疼',u'酸痛',u'酸緊',u'僵直',u'僵硬'\
         ,u'廣泛性軸索損傷',u'撕裂性傷口',u'撕裂傷',u'撕裂擦傷',u'撞擊傷',u'線性骨折',u'線條性挫傷'\
         ,u'機能障礙',u'燙傷',u'頭痛',u'頸神經病變',u'壓迫性骨折',u'壓傷',u'壓擦傷',u'擦傷',u'濕疹'\
         ,u'膿傷',u'斷掌',u'斷裂',u'關節病變',u'關節症',u'觸痛']
print 'list wound set'

position = [u'十字韌帶',u'三叉神經根',u'上臂',u'下巴',u'下半身',u'下背部',u'下腿',u'下頰',u'大腳趾骨'\
            ,u'大腿',u'小指',u'小腿',u'小腿皮膚',u'內踝',u'尺骨',u'手小指',u'手肘',u'手指',u'手腕',u'牙齒'\
            ,u'肋骨',u'尾胝部',u'尾骨',u'尾椎',u'肝臟',u'足底',u'足部',u'拇指',u'股骨',u'股骨上踝'\
            ,u'股骨幹',u'股骨頸',u'股骨頸外髁',u'肩胛骨頸部',u'肩峰關節',u'肩部',u'肩鎖骨',u'肱骨'\
            ,u'近端肱骨',u'枷胸骨',u'玻璃體'u'背部',u'胝骨',u'胝骨及尾骨',u'神經脊柱'\
            ,u'胸部',u'胸部第十二節',u'胸椎',u'胸腔',u'胸腹部',u'胸壁',u'脊椎',u'脊髓',u'骨盆',u'側肩部'\
            ,u'側恥骨',u'側恥骨環骨',u'側橈骨末端',u'側頸',u'側頸部',u'側額',u'側額頭',u'眼內',u'眼皮'\
            ,u'眼角膜',u'眼周區',u'眼眶',u'眼瞼',u'第一掌拇關節處掌面皮膚',u'第三蹠骨',u'脛骨',u'脛骨平台'\
            ,u'脛腓骨',u'連枷胸',u'掌骨',u'椎弓',u'硬腦膜',u'腓骨',u'腕關節',u'視網膜',u'腦部'\
            ,u'腦頭皮',u'腰椎',u'腰椎椎弓',u'腹骨盆腔',u'腹部',u'綠內障',u'鼻骨',u'嘴唇'\
            ,u'膝十字韌帶',u'膝功能關節',u'橈骨',u'頭皮',u'頭骨',u'頭部',u'頭部側臚骨',u'頭部頂部'\
            ,u'頭部顱內',u'頭頸部',u'頸神經',u'頸神經脊柱',u'頸側',u'頸部',u'頸部下方側鎖骨'\
            ,u'頸部肌肉韌帶',u'頸部脊椎',u'頸部脊髓',u'頸部退化性頸椎炎',u'頸部動脈',u'頸部經根',u'頸椎'\
            ,u'頸鎖骨',u'環骨',u'薦椎',u'軀幹',u'鎖骨',u'雙手',u'雙臂',u'顏面'\
            ,u'顏面骨',u'顏面骨骼',u'顏面竇',u'顱內',u'顱骨',u'顳部'\
            ,u'左眼',u'右眼',u'左臉',u'右臉',u'前臂',u'左胸',u'右胸'\
            ,u'趾',u'臂',u'臉',u'腦',u'膝',u'頸',u'肺',u'足',u'腳',u'踝',u'眉',u'背',]
print 'list position set'
# Out:
# list wound set
# list position set

# %%
def search_wound(line):
    for w in wound:
        if w in line:
            line = line.replace(w,'')
    return line

def search_position(line):
    for p_in in position:
        if p_in in line:
            if any(w in line for w in wound):
                line = search_wound(line).replace(p_in,'')
                for p in position:
                    line = line.replace(p,'')
                print line
                print
                break
                

# print 'def search_position(x) set'

import codecs
import os
place = u'金門'
location = 'project\\%s\\'%place
all_files = os.path.abspath(location)
for x in os.listdir(all_files):
    if x[0]!= u'c' and x[0]!= u'W':
        with codecs.open(os.path.join(location,x),'r','utf-8') as f:
            print x
            for line in f:
                search_position(line)
# Out:
# 金門_101_訴_19.txt
#     受有、顱、下、左股、
#
#     本件車禍重創，引發壓力症候群，導致嚴重型憂鬱
#
#     健亦備感艱辛。且因引發持續性，併發失眠
#
#     部、顱、下、左股、齒槽骨
#
#     受有、顱、下、左股、
#
#     。暨本件車禍事故造成原告受有、顱、硬
#
#     膜下、左股、齒槽等，更因而罹患嚴
#
# 金門_101_訴_26.txt
#     並壓過陳詩坤頭顱，致陳詩坤頭顱，漿外溢當場死亡
#
# 三、陳詩坤因上開車禍頭顱，漿外溢當場死亡。
#
#     自用大貨車發生車禍。陳詩坤因上開車禍頭顱，漿外
#
#         詩坤致陳詩坤頭顱，漿外溢當場死亡等情，有道
#
# 金門_101_訴_33.txt
#     於之犯意聯絡，毆打伊及身體，致伊受有撞擊
#
#     傷併、上肢多處擦磨傷等，被告陳致恩、楊宇
#
#     元有單據，餘1910元無單據），另伊因，需母親協
#
#     、林偉豪出手毆打原告，致原告受有併
#
#     、上肢多處擦磨傷等。
#
#     眼併、上肢多處擦磨傷等等語，為兩造
#
#     告所勢為觀察，其部位及程度為「併血
#
#     日所勢為「左併皮下、左手、
#
#     右手併食指基部裂傷」，有廣川醫院診斷證明書
#
#     致恩等人原告，造成原告所屬船隻必備人員不、無法
#
#     生衝突，致受有併、上肢多處擦磨傷等
#
# 金門_101_訴_36.txt
#     陳志帆之，致原告陳銘傑受有雙側併、
#
#     擦磨傷等，訴外人陳志帆則受有併
#
#     、上肢多處擦磨傷等。被告楊宇聖、林偉豪不法侵
#
#     (二)交通費用：15,482元，原告因由配偶陪同搭飛機
#
#       雙側併、擦磨傷等精神及肉體受
#
# 金門_101_訴_44.txt
#     受有左側及閉鎖性。
#
#                    月仍須門診，仍時感，手部無力
#
#     查原告因此次之車禍而有左側及閉鎖性，歷經
#
#     三次之開刀，骨髓內並接上鋼釘，金門署立醫院鑑
#
#        側及閉鎖性，惟以原告所受之，
#
#     (二)又原告因系爭車禍受有左側及閉鎖性之
#
# ...
