# %%
vechical = {
u'腳踏車':[u'腳踏自行車'],
u'三輪車':[u'三輪腳踏車',u'農用三輪車',u'三輪車',u'拼裝動力三輪車',u'拼裝三輪車',u'機器三輪車',u'馬達三輪車',u'摩拖三輪車',u'電動三輪車',u'動力三輪車',u'單速三輪車',u'大型三輪車',u'醫療用電三輪車',u'電動代步車',u'拼裝附動力三輪車',u'殘障三輪車',u'身心障礙者生活輔助器具特製車',u'殘障動力三輪車'],
u'小客車':[u'不明車號汽車',u'不明車輛',u'不明汽車',u'自小客',u'自小客車',u'自用小客車',u'租賃小客車',u'租賃用小客車',u'休旅車'],
u'營業小客車':[u'計程車',u'營業小客車',u'營業用小客車'],
u'輕型機車':[u'機器腳踏車',u'普通輕型機車',u'電動機車'],
u'重型機車':[u'警用重型機車',u'重型機車',u'普通重機車',u'普通重型機車',u'電動重型機車'],
u'大客車':[u'遊覽車',u'出租遊覽車',u'大客車',u'營業大客車',u'公車',u'客運'],
u'農用車':[u'農耕機',u'農耕曳引機',u'農耕曳引車',u'農耕用車'],
u'火車':[u'火車',u'電力機車'],
u'卡車':[u'曳引車',u'全拖車',u'貨櫃車',u'聯結車',u'大卡車',u'貨車'],
u'拖板車':[u'拖板車',u'電動拖板車']
}
#u'特種車':[u'油罐車',u'垃圾車',u'灑水車',u'吊車',u'救濟車',u'消防車',u'救護車',u'警備車',u'憲警巡邏車',u'工程車',u'教練車',u'殘障用特製車',u'郵車',u'清掃車',u'水肥車',u'囚車',u'殯儀館運靈車',u'靈車',u'油罐車',u'灑水車',u'垃圾車',u'運鈔車',u'救護車']

def find_vechical(ls):
    Plaintiffs_vechical = []
    Defendants_vechical = []
    for i in range(len(ls)):#------------------------1st for
                                #ls[i]
        for v in vechical.keys():#------------------2nd for
            for c in vechical[v]:#------------------3rd for
                if c in ls[i]:
#                     print v,c,ls[i],'if c in ls[i]'
                    if u'原告' not in ls[i] and u'被告' not in ls[i]:#若是兩個都沒有往前早
#                         print ls[i],'fuck'
                        for minus in range(1,3):
                            if u'原告' in ls[i-minus] and u'被告' in ls[i-minus]:
                                if ls[i-minus].find(u'原告')< ls[i-minus].find(u'被告'):
#                                     print u'被告',v,c,ls[i-minus],ls[i]
#                                     print '----'
                                    
                                    Defendants_vechical.append(v)
                                    break
                                
                                else:
#                                     print u'原告',v,c,ls[i-minus],ls[i]
#                                     print '----'
                                    
                                    Plaintiffs_vechical.append(v)
                                    break
                            
                            elif u'原告' in ls[i-minus]:
#                                 print u'原告',v,c,ls[i-minus]
#                                 print '----'
                                
                                Plaintiffs_vechical.append(v)
                                break
                            
                            elif u'被告' in ls[i-minus]:
#                                 print u'被告',v,c,ls[i-minus]
#                                 print '----'
                                
                                Defendants_vechical.append(v)
                                break
                                
                    elif u'原告' in ls[i] and u'被告' in ls[i]:
                        if ls[i].find(u'被告') < ls[i].find(u'原告') < ls[i].find(c):
#                             print u'原告',v,c
#                             print ls[i]
#                             print '----'
                            
                            Plaintiffs_vechical.append(v)
                            continue
                        
                        else:
#                             print u'被告',v,c
#                             print ls[i]
#                             print '----'
                            
                            Defendants_vechical.append(v)
                            continue
            
                    elif u'原告' in ls[i]:
#                         print u'原告',v,c
#                         print ls[i]
#                         print '----'
                        
                        Plaintiffs_vechical.append(v)
                        continue

                    elif u'被告' in ls[i]:
#                         print u'被告',v,c
#                         print ls[i]
#                         print '----'
                        
                        Defendants_vechical.append(v)
                        continue
     
    Plaintiffs_vechical = list(set(Plaintiffs_vechical))
    Defendants_vechical = list(set(Defendants_vechical))
    plv = ','.join(Plaintiffs_vechical) if len(Plaintiffs_vechical) != 0 else 0
    dev = ','.join(Defendants_vechical) if len(Defendants_vechical) != 0 else 0
    return plv,dev
print 'def find_vechical(content) set'
# Out:
# def find_vechical(content) set

# %%
import os
import codecs
import re
os.remove(u'attr_vechical.txt')
no = 0
dic = {
    u'原告車輛':'',
    u'被告車輛':''
}
def get_vechicals(pos):
    location = u'project\\%s\\'%pos
    all_files = os.path.abspath(location)
    for x in os.listdir(all_files)[34:40]:
        with codecs.open(os.path.join(location,x),'r','utf-8') as f:
            no+=1
            print no,x  #高雄_100_岡保險小_17.txt
            ls = []
            for line in f:
                if line.strip() != 0:
                    ls.append(line.strip().replace(u'　',u'').replace(u' ',u''))
        for i in range(len(ls)):
            if u'事實' in ls[i] or u'理由' in ls[i]:
                short = ''.join(ls[i:])
                break
        delimiter = "，|。|、".decode('utf-8')
        ls = re.split(delimiter, short)[:20]
        dic[u'原告車輛'],dic[u'被告車輛'] = find_vechical(ls)
        x=x.split(u'.')[0]
        with codecs.open(u'attr_vechical.txt','a','utf-8') as fv:
            if dic[u'原告車輛']!=0:
                if u',' not in dic[u'原告車輛']:
                    fv.write('%s\t%s\t%s\r\n'%(x,u'P',dic[u'原告車輛']))
                else:
                    for z in dic[u'原告車輛'].split(u','):
                        fv.write('%s\t%s\t%s\r\n'%(x,u'P',z))

            if dic[u'被告車輛']!=0:
                if u',' not in dic[u'被告車輛']:
                    fv.write('%s\t%s\t%s\r\n'%(x,u'D',dic[u'被告車輛']))
                else:
                    for z in dic[u'被告車輛'].split(u','):
                        fv.write('%s\t%s\t%s\r\n'%(x,u'D',z))
#         dic[u'被告車輛']
#     print u'原告車輛',dic[u'原告車輛']
#     print u'被告車輛',dic[u'被告車輛']
#     print 
#     print '\n'.join(ls)
#     print '----------------'
#     for x in ls:
#         print x
print 'done'
# Out:
# 1 高雄_100_岡簡_334.txt
# 2 高雄_100_岡簡_346.txt
# 3 高雄_100_岡簡_353.txt
# 4 高雄_100_岡簡_360.txt
# 5 高雄_100_岡簡_366.txt
# 6 高雄_100_岡簡_393.txt
# done

# %%
# -*- coding:utf-8 -*-
identification_doc = [u'道路交通事故調查報告表',u'調查報告表',u'現場勘查報告',\
    u'道路交通事故初步分析研判表',u'道路交通事故初步分析表',\
    u'車輛行車事故鑑定委員會鑑定意見書',u'鑑定意見書',\
    u'道路交通事故當事人登記聯單',u'車險理賠申請書',\
    u'道路交通事故現場圖',u'現場圖',u'鑑定委員會',\
    u'交通事故鑑定委員會',u'車輛行車事故鑑定會',\
    u'交通部公路總局車輛行車事故鑑定會',u'鑑定報告',\
    u'交通部公路總局車輛行車事故鑑定覆議會',u'行車事故鑑定覆議會']

def get_identification_doc(content):
    ans = 0
    for i in ls:
        if i in content:
            return 1
            break
    return 0

print 'def get_identification_doc(content) set'

import os
import codecs

def get_identification(pos):
    no=0
    location = u'project\\%s\\'%pos
    all_files = os.path.abspath(location)
    for x in os.listdir(all_files)[:10]:
        with codecs.open(os.path.join(location,x),'r','utf-8') as f:
            no+=1
            print no,x
            ls = []
            for i in f:
                ls.append(i.strip().replace(u'　',u'').replace(u' ',u''))
        content = ''.join(ls)
        x = x.split(u'.')[0]
        with codecs.open(u'attr_identification.txt','a','utf-8') as fv:
            fv.write('%s\t%d'%(x,get_identification_doc(content)))

ls = [u'臺北',u'士林',u'新北',u'宜蘭'\
     ,u'基隆',u'桃園',u'新竹',u'苗栗'\
     ,u'臺中',u'彰化',u'南投',u'雲林'\
     ,u'嘉義',u'臺南',u'高雄',u'花蓮'\
     ,u'臺東',u'屏東',u'澎湖',u'金門'\
     ,u'連江']
for pos in ls:
    print pos
    get_identification(pos)

print 'done'
# Out:
# def get_identification_doc(content) set
# 臺北
# 1 臺北_100_保險_107.txt
# 2 臺北_100_保險_8.txt
# 3 臺北_100_勞訴_244.txt
# 4 臺北_100_勞訴_74.txt
# 5 臺北_100_北保險小_1.txt
# 6 臺北_100_北保險小_7.txt
# 7 臺北_100_北勞簡_57.txt
# 8 臺北_100_北國小_1.txt
# 9 臺北_100_北國小_8.txt
# 10 臺北_100_北國小_9.txt
# 士林
# 1 士林_100_勞訴_55.txt
# 2 士林_100_勞訴_56.txt
# 3 士林_100_勞訴_60.txt
# 4 士林_100_勞訴_61.txt
# 5 士林_100_勞訴_79.txt
# 6 士林_100_士小_1020.txt
# 7 士林_100_士小_1024.txt
# 8 士林_100_士小_1025.txt
# 9 士林_100_士小_1026.txt
# 10 士林_100_士小_1035.txt
# 新北
# 1 新北_100_保險_10.txt
# 2 新北_100_保險_15.txt
# 3 新北_100_保險_24.txt
# 4 新北_100_保險_25.txt
# 5 新北_100_保險_27.txt
# 6 新北_100_保險_28.txt
# 7 新北_100_保險_35.txt
# 8 新北_100_保險_36.txt
# 9 新北_100_保險_39.txt
# 10 新北_100_保險_4.txt
# 宜蘭
# 1 宜蘭_100_宜小_153.txt
# 2 宜蘭_100_宜小_175.txt
# 3 宜蘭_100_宜小_181.txt
# 4 宜蘭_100_宜小_183.txt
# 5 宜蘭_100_宜小_196.txt
# 6 宜蘭_100_宜小_5.txt
# 7 宜蘭_100_宜小_63.txt
# 8 宜蘭_100_宜小_64.txt
# 9 宜蘭_100_宜小_90.txt
# 10 宜蘭_100_宜簡_112.txt
# 基隆
# 1 基隆_100_基小_1018.txt
# 2 基隆_100_基小_1141.txt
# 3 基隆_100_基小_126.txt
# 4 基隆_100_基小_1289.txt
# 5 基隆_100_基小_1400.txt
# 6 基隆_100_基小_1424.txt
# 7 基隆_100_基小_1501.txt
# 8 基隆_100_基小_1507.txt
# 9 基隆_100_基小_1624.txt
# 10 基隆_100_基小_1652.txt
# 10 嘉義_100_嘉小_198.txt
# 臺南
# 1 臺南_100_保險_1.txt
# 2 臺南_100_南小_101.txt
# 3 臺南_100_南小_1011.txt
# 4 臺南_100_南小_1023.txt
# 5 臺南_100_南小_1101.txt
# 6 臺南_100_南小_1102.txt
# 7 臺南_100_南小_1106.txt
# 8 臺南_100_南小_1158.txt
# 9 臺南_100_南小_167.txt
# 10 臺南_100_南小_224.txt
# 高雄
# 1 高雄_100_勞訴_11.txt
# 2 高雄_100_勞訴_68.txt
# 3 高雄_100_勞訴_69.txt
# 4 高雄_100_勞訴_76.txt
# 5 高雄_100_勞訴_84.txt
# 6 高雄_100_岡保險小_1.txt
# 7 高雄_100_岡保險小_11.txt
# 8 高雄_100_岡保險小_12.txt
# 9 高雄_100_岡保險小_17.txt
# 10 高雄_100_岡保險小_2.txt
# 花蓮
# 1 花蓮_100_建_5.txt
# 2 花蓮_100_玉小_38.txt
# 3 花蓮_100_玉小_5.txt
# 4 花蓮_100_玉簡_5.txt
# 5 花蓮_100_花小_20.txt
# 6 花蓮_100_花小_216.txt
# 7 花蓮_100_花小_254.txt
# 8 花蓮_100_花小_260.txt
# 9 花蓮_100_花小_267.txt
# 10 花蓮_100_花小_28.txt
# 臺東
# 1 臺東_100_東小_100.txt
# 2 臺東_100_東小_129.txt
# 3 臺東_100_東小_130.txt
# 4 臺東_100_東小_136.txt
# 5 臺東_100_東小_150.txt
# 6 臺東_100_東小_153.txt
# 7 臺東_100_東小_180.txt
# 8 臺東_100_東小_28.txt
# 9 臺東_100_東小_3.txt
# 10 臺東_100_東小_37.txt
# 屏東
# 1 屏東_100_屏小_142.txt
# 2 屏東_100_屏小_148.txt
# 3 屏東_100_屏小_155.txt
# 4 屏東_100_屏小_166.txt
# 5 屏東_100_屏小_213.txt
# 6 屏東_100_屏小_232.txt
# 7 屏東_100_屏小_234.txt
# 8 屏東_100_屏小_255.txt
# 9 屏東_100_屏小_301.txt
# 10 屏東_100_屏小_322.txt
# 澎湖
# 1 澎湖_100_保險_1.txt
# 2 澎湖_101_訴_29.txt
# 3 澎湖_101_訴_42.txt
# 4 澎湖_101_訴_68.txt
# 5 澎湖_102_訴_11.txt
# 6 澎湖_102_訴_26.txt
# 7 澎湖_102_重勞訴_2.txt
# 8 澎湖_103_保險_1.txt
# 9 澎湖_103_訴_24.txt
# 10 澎湖_103_馬保險小_4.txt
# 金門
# 1 金門_100_訴_24.txt
# 2 金門_101_城簡_4.txt
# 3 金門_101_訴_26.txt
# 4 金門_101_訴_33.txt
# 5 金門_101_訴_36.txt
# 6 金門_101_訴_38.txt
# 7 金門_101_訴_44.txt
# 8 金門_101_訴_54.txt
# 9 金門_102_城小_35.txt
# 10 金門_102_訴_2.txt
# 連江
# 1 連江_101_小_8.txt
# 2 連江_101_簡_7.txt
# 3 連江_93_訴_20.txt
# 4 連江_94_訴_2.txt
# 5 連江_95_簡_10.txt
# 6 連江_96_小_1.txt
# 7 連江_97_小_6.txt
# 8 連江_97_簡_12.txt
# 9 連江_98_小_8.txt
# done
