# %%
import os.path
import codecs
place = '金門'
#name = '金門_103_城簡_40.txt'.decode('utf-8')
dic = []
location = 'project\%s\\'%place.decode('utf-8') #project\台北\
all_files = os.path.abspath(location)
for x in os.listdir(all_files):
    if x[0]!='W' and x[0]!='c':
        with open('%s%s'%(location,x),'r') as f:
            file_list = []
            for line in f:
                file_list.append(line.strip()\
                 .replace(' ','').replace('　','').decode('utf-8'))
            num  = len(file_list)
            #print 'ok',num
            for i in range(0,num):
                if file_list[i].find('主文'.decode('utf-8'))!= -1:
                    for terminal in range(1,10):
                        if file_list[i+terminal].find('新臺幣'.decode('utf-8'))!=-1:
                            nt = file_list[i+terminal].find(u'新臺幣')
                            dollars = file_list[i+terminal].find(u'元')
                            print x,file_list[i+terminal][nt+3:dollars]
                            break
                        break
# Out:
# 金門_101_城簡_4.txt 壹拾萬玖仟肆佰陸拾玖
# 金門_101_訴_19.txt 參拾壹萬肆仟參佰陸拾肆
# 金門_101_訴_33.txt 壹拾萬玖仟參佰玖拾
# 金門_101_訴_38.txt 貳拾壹萬貳仟參佰貳拾柒
# 金門_101_訴_44.txt
# 金門_102_城簡_79.txt 壹佰柒拾伍
# 金門_102_訴_2.txt 陸拾萬貳仟零柒拾肆
# 金門_102_訴_66.txt 壹佰零伍萬伍仟捌佰貳拾
# 金門_102_重訴_12.txt 貳佰參拾壹萬陸仟伍佰柒拾
# 金門_103_城簡_40.txt 壹萬伍仟
# 金門_103_訴_47.txt 陸萬
# 金門_103_訴_66.txt 參佰零肆萬參仟參佰參拾捌
# 金門_90_小上_1.txt 伍仟
# 金門_93_訴_47.txt 壹佰肆拾萬
# 金門_93_訴_50.txt 肆拾壹萬壹仟柒佰柒拾
# 金門_96_訴_21.txt 貳拾萬壹仟玖佰貳拾貳
# 金門_96_訴_29.txt 柒拾捌萬玖仟貳佰
# 金門_96_重國_3.txt 肆拾陸萬肆仟壹佰
# 金門_97_訴_19.txt 壹佰柒拾陸萬貳仟伍佰肆拾貳
# 金門_97_重訴_11.txt 壹佰拾柒萬陸仟零玖拾
# 金門_97_重訴_6.txt 拾貳萬參仟壹佰伍拾貳
# 金門_98_簡上_8.txt 壹拾肆萬壹仟壹佰貳
# 金門_98_訴_1.txt 貳拾柒萬陸仟肆佰捌拾伍
# 金門_98_訴_2.txt 玖拾玖萬參仟捌佰
# 金門_98_訴_23.txt 壹佰拾萬
# 金門_98_訴_30.txt 壹佰壹拾柒萬柒仟貳佰零壹
# 金門_98_重訴_4.txt 壹仟柒佰零玖萬仟零玖拾貳
# 金門_99_訴_23.txt 貳拾陸萬陸仟捌佰貳拾
# 金門_99_訴_28.txt 貳拾玖萬伍仟貳佰零肆
# 金門_99_訴_35.txt 伍萬
# 金門_99_訴_38.txt 壹拾參萬

# %%
money = '壹拾參萬'.decode('utf-8')
#------------------------
n = 0
m = 0
dic={}
num=0
total = 0

money_unit ={u'萬':10000,u'仟':1000,u'佰':100,u'拾':10}
number={u'零':0,u'壹':1,u'貳':2,u'參':3,u'肆':4,\
        u'伍':5,u'陸':6,u'柒':7,u'捌':8,u'玖':9}
print money
print 'len ',len(money)
for x in range(0,len(money)):
    if total==len(money):
        break
    if money[total] in number:#---------------------------------1
        n = number[money[total]]
    else:
        m = money_unit[money[total]]
    total+=1
    if total==len(money):
        break
    if money[total] in number:#---------------------------------2
        n = number[money[total]]
    else:
        m = money_unit[money[total]]
    total+=1
    print 'n - %d ; m - %d'%(n,m)
# Out:
# 壹拾參萬
# len  4
# n - 1 ; m - 10
# n - 3 ; m - 10000

# %%
'''
get the lawyer and the result
function get_result
'''
def get_result(name,place):
    location = 'project\%s\\'%place.decode('utf-8') #project\台北\
    #open the Verdict
    file_name = name#.decode('utf-8')
    with open('%s%s'%(location,name),'r') as f:
        file_list=[]
        #print type(f)
        for line in f:
            file_list.append(line.strip()\
                .replace(' ','').replace('　','').decode('utf-8'))
        print 'ok'
    #print content

    #function Plaintiff_win()-----return true or false
    #check who win the lawsuit
    '''a = 3
    ans = True if a == 3 else False'''
    def Plaintiff_win(file_list):
        x = '被告應給付原告'.decode('utf-8')
        for x in file_list:
            if x.find('被告應給付原告'.decode('utf-8')) != -1:
                answer = True
                break
            else:
                answer = False

        return answer
    result = u'原告 - 勝訴' if Plaintiff_win(file_list) else u'原告 - 敗訴'
    print result

    #catch lawyer
    num  = len(file_list)
    Plaintiffs_lawyer = []
    Defendants_lawyer = []
    for i in range(0,num):

        #find Plaintiff 's lawyer
        if file_list[i].find('原告'.decode('utf-8')) != -1:
            for terminal in range(1,20):
                next_line = file_list[i+terminal]
                if next_line.find('被告'.decode('utf-8')) != -1:
                    break
                if next_line.find('律師'.decode('utf-8')) != -1:
                    if len(next_line)>5:
                        people = next_line.find('人'.decode('utf-8'))
                        Plaintiffs_lawyer.append(next_line[people+1:])
                    else:
                        Plaintiffs_lawyer.append(next_line)


        #find Defendant 's lawyer
        if file_list[i].find('被告'.decode('utf-8')) != -1:
            for terminal in range(1,20):
                next_line = file_list[i+terminal]
                if next_line.find('主文'.decode('utf-8')) != -1:
                    break
                if next_line.find('律師'.decode('utf-8')) != -1:
                    if len(next_line)>5:
                        people = next_line.find('人'.decode('utf-8'))
                        Defendants_lawyer.append(next_line[people+1:])
                    else:
                        Defendants_lawyer.append(next_line)
            break

    if len(Plaintiffs_lawyer) == 0:
        print u'原告沒有律師'
    else:
        for x in Plaintiffs_lawyer:
            print u'原告律師 - %s'%x
    if len(Defendants_lawyer) == 0:
        print u'被告沒有律師'
    else:
        for x in Defendants_lawyer:
            print u'被告律師 - %s'%x

#function end---------------------------------------------------------------#
print 'ok'


# -*- coding:uft-8 -*-
import os.path
#import codecs
#def check(pos):
place = str('金門')
location = 'project\%s\\'%place.decode('utf-8') #project\台北\
all_files = os.path.abspath(location)
#print all_files
for x in os.listdir(all_files):
    if x[0]!='c' and x[0]!='W':
        #print type(x)
        get_result(x,place)
# Out:
# ok
# ok
# 原告 - 敗訴
# 原告律師 - 宋一心律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告律師 - 鄭崇煌律師
# 原告律師 - 曹宗彝律師
# 被告律師 - 謝岳龍律師
# 被告律師 - 曹珮怡律師
# ok
# 原告 - 勝訴
# 原告律師 - 林峻義律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 李志澄律師
# 原告律師 - 林美伶律師
# 被告律師 - 吳奎新律師
# ok
# 原告 - 敗訴
# 原告律師 - 李志澄律師
# 原告律師 - 林美伶律師
# 被告律師 - 吳奎新律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告律師 - 沈炎平律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 吳奎新律師
# 被告律師 - 陳達成律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 沈炎平律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告律師 - 鄭成東律師法律扶助基金會指派律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告律師 - 陳詩文律師
# 被告律師 - 蔡伊雅律師
# 被告律師 - 賴俊維律師
# ok
# 原告 - 敗訴
# 原告律師 - 顧定軒律師
# 被告律師 - 李志澄律師
# 被告律師 - 林美伶律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 郭振茂律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 鄭庭壽律師
# 被告律師 - 李志澄律師
# 被告律師 - 林國明律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 陳素鶯律師
# 被告律師 - 黃怡騰律師
# 被告律師 - 楊克成律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 李志澄律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告律師 - 盧烽池律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 辛銀珍律師
# 被告律師 - 丁志達律師
# 被告律師 - 陳錫川律師
# 被告律師 - 朱峻賢律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告律師 - 丁志達律師
# 被告律師 - 陳錫川律師
# 被告律師 - 辛銀珍律師
# 被告律師 - 李志澄律師
# 被告律師 - 林美伶律師
# 被告律師 - 蔡鴻斌律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告律師 - 李志澄律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告律師 - 共同訴訟代林春華律師
# 被告律師 - 共同史乃文律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告律師 - 姜志俊律師
# ok
# 原告 - 勝訴
# 原告律師 - 李志澄律師
# 原告律師 - 林美伶律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告律師 - 李志澄律師
# 原告律師 - 林美伶律師
# 被告律師 - 辛銀珍律師
# ok
# 原告 - 勝訴
# 原告律師 - 鄭崇煌律師
# 被告律師 - 李志澄律師
# 被告律師 - 林國明律師
# ok
# 原告 - 敗訴
# 原告律師 - 共同訴訟代林春華律師
# 被告律師 - 丁志達律師
# 被告律師 - 陳錫川律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 陳素鶯律師
# 被告沒有律師
# ok
# 原告 - 敗訴
# 原告律師 - 吳奎新律師
# 原告律師 - 陳添信律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 吳奎新律師
# 原告律師 - 陳添信律師
# 被告律師 - 李志澄律師
# 被告律師 - 林國明律師
# ok
# 原告 - 敗訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告律師 - 沈炎平律師
# 被告律師 - 蕭佩芬律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告律師 - 丁志達律師
# 被告律師 - 陳錫川律師
# 被告律師 - 方耀德律師
# 被告律師 - 王東山律師
# 被告律師 - 李美寬律師
# 被告律師 - 許富雄律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告律師 - 陳錫川律師
# 被告律師 - 丁志達律師
# 被告律師 - 方耀德律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 沈炎平律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告沒有律師
# 被告沒有律師
# ok
# 原告 - 勝訴
# 原告律師 - 沈炎平律師
# 被告沒有律師
